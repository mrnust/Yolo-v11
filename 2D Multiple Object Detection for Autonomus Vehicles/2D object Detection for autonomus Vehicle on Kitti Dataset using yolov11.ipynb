# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive'
import os

directory = '/content/drive/My Drive'
contents = os.listdir(directory)
print(contents)
# Out:
# ['Linaer Algebra.zip', 'Calculus.zip', 'Maths for ML.pdf', 'Rayyan Shakoori -Internship Offer Letter .pdf', 'Rayyan_updated_resume.pdf', 'MLS Slides (3).zip', 'ML Book Awesome (3).pdf', 'ML Book Awesome (2).pdf', 'MLS Slides (2).zip', 'ML Book Awesome (1).pdf', 'MLS Slides (1).zip', 'Deep Learning Andrew (1).pdf', 'Letter.gdoc', 'Resume (5).gdoc', 'Resume (4).gdoc', 'Rayyan Shakoori -Internship Offer Letter  (1).gdoc', 'Rayyan Shakoori -Internship Offer Letter .gdoc', 'Rayyan_resume.com.pdf', '18.1 Notes Backtracking - Rat in a Maze.gdoc', '19.1.gdoc', '20.1.gdoc', '22.4 Linked List Apni Kaksha_watermark (1).gdoc', '22.11 Put Even position nodes after Odd position nodes - Notes_watermark.gdoc', 'Resume (3).gdoc', 'Colab Notebooks', 'Image Segmentation', 'Semantic Segmentation duck', 'Resume (2).gdoc', 'M.Rayyan_resume.pdf', 'Dog and Cat Image classifier', 'Cat and Dog Classifier using Yolov8.ipynb', 'Duck Semantic Segmentation.ipynb', 'You have been appointed CEO of new rapidly incre
# ...

# %%
# !pip install ultralytics

import sys
# !{sys.executable} -m pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 881.3/881.3 kB 36.5 MB/s eta 0:00:00
# ...

# %%
# from ultralytics import YOLO

# # Load a model
# model = YOLO("yolov8n.pt")  # build a new model from scratch

# # Use the model
# model.train(data="/content/drive/My Drive/Kitti dataset 500/Copy of config.yaml", epochs=50,batch=1)  # train the model



from ultralytics import YOLO


model = YOLO('yolo11n.pt')

# Use the model
model.train(data="/content/drive/My Drive/Kitti dataset 500/Copy of config.yaml", epochs=50,batch=1)  # train the model
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.36M/5.36M [00:00<00:00, 163MB/s]
# WARNING ⚠️ yolo11n.pt appears to require 'dill', which is not in Ultralytics requirements.
# AutoInstall will run now for 'dill' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official Ultralytics model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['dill'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 11.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 2.3s, installed 1 package: ['dill']
# ...

# %%
from ultralytics import YOLO

# Load the previously trained model (the checkpoint after 50 epochs)
model = YOLO('/content/runs/detect/train/weights/last.pt')  # Change this to your actual checkpoint path

# Resume training for additional epochs
model.train(data="/content/drive/My Drive/Kitti dataset 500/Copy of config.yaml", epochs=50, batch=1)
# Out:
# Ultralytics 8.3.0 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !scp -r /content/runs '/content/drive/My Drive/Kitti dataset 500'

# !export LC_ALL=C.UTF-8
# !scp -r /content/runs1yolov11 '/content/drive/My Drive/Kitti dataset 500'

# Set the locale to UTF-8
# !export LC_ALL=C.UTF-8

# Use rsync for copying files as it may handle paths with spaces better than scp
# !rsync -r '/content/runs' '/content/drive/My Drive/Kitti dataset 500/complete100'
